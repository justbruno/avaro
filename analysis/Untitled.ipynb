# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
portfolios = []
with open('../optimization/results.csv', 'r') as f:
    for l in f:
        r = eval(l)
        alpha = r[0]
        thr = r[1]
        portfolio = r[3]
        portfolios.append(portfolio)

# %%
min_ts = np.min(all_ts)
max_ts = np.max(all_ts)

# %%
for p in portfolios:
    x = [i[0] for i in p]
    y = [i[1] for i in p]
    #plt.xlim(min_ts, max_ts)
    plt.plot(y)

# %%
all_ts = [i[0] for i in p for p in portfolios]

# %%
portfolios
# Out:
# [[(1677591392.0, -0.03520005493760081),
#   (1677591393.0, -0.07754657592320058),
#   (1677591393.0, -0.1143572366015988),
#   (1677591394.0, -0.19849711377920443),
#   (1677591394.0, -0.25767387125119967),
#   (1677591395.0, -0.2974087782272079),
#   (1677591396.0, -0.7272671343872048),
#   (1677591398.0, -0.2507556888545821),
#   (1677591398.0, -0.30226003354790976),
#   (1677591398.0, -0.3180496229559253),
#   (1677591398.0, -0.3653515053239147),
#   (1677591398.0, -0.36605584396070867),
#   (1677591430.0, -0.06159653738947668),
#   (1677591433.0, -0.7897472100871141),
#   (1677591434.0, -0.2967085595549719),
#   (1677591445.0, 0.48043093409788185),
#   (1677591446.0, 0.649676846572234),
#   (1677591448.0, 0.7250531741786688),
#   (1677591450.0, 0.8914648915597922),
#   (1677591452.0, 0.9123194267093311),
#   (1677591453.0, 0.8376907713162467),
#   (1677591454.0, 0.8690529088179595)],
#  [(1677591463.0, -0.03519997583359924), (1677591465.0, 0.05917677846170655)],
# ...
